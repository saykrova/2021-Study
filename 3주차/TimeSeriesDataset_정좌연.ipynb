# %% [markdown]
# # 시계열 데이터의 이해 : 시간, 순서에 따른 수치형 관측데이타
# ### 1) a collection of observation
# ### 2) sequentially in time
# ###  2016년 태양에너지 생산(GWh 단위 측정) 라인차트
# ![1696384c-d12d-438c-8dc5-0f6be5417271.png](data:image/png;base64,...)

# %%
import os
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# Size 50개의 정규분포 샘플 추출, loc: 평균, scale: 표준편차
zero_mean_series = np.random.normal(loc=0.0, scale=1., size=50)
zero_mean_series
# Out:
# array([ 0.81403481, -1.42295064, -1.21082933, -0.36125285,  0.46047201,
#        -1.23152906,  0.41311201,  0.43902806,  0.25942921,  1.15998273,
#        -0.92436551,  0.85606322, -0.38012904, -1.74669424,  0.5464819 ,
#         1.26568824, -0.61035931, -0.44077843,  0.75273335,  0.40380424,
#         0.8846211 , -0.24738664,  0.82681501, -0.89773519,  1.37819548,
#         1.84134094,  0.1615065 ,  0.39566592,  1.36183243,  0.98544707,
#        -0.01733454,  0.42162961, -0.08492589, -0.06917287, -0.85688814,
#         0.57761669,  0.63857463, -0.32447791,  0.62554012,  0.05055761,
#         1.05400092, -0.58137999,  0.25678885, -0.39968803, -0.24406788,
#         1.79273087,  0.86346826,  1.30486422, -0.33378336, -0.88286686])

# %%
plt.figure(figsize=(16, 8))
g = sns.lineplot(data=zero_mean_series)
g.set_title('Zero mean model')
g.set_xlabel('Time index')
plt.show()

# %%
random_walk = np.cumsum(zero_mean_series)
random_walk
# Out:
# array([ 0.81403481, -0.60891583, -1.81974516, -2.18099802, -1.72052601,
#        -2.95205507, -2.53894306, -2.099915  , -1.8404858 , -0.68050307,
#        -1.60486858, -0.74880536, -1.1289344 , -2.87562864, -2.32914674,
#        -1.0634585 , -1.67381781, -2.11459624, -1.36186289, -0.95805865,
#        -0.07343755, -0.32082419,  0.50599082, -0.39174437,  0.98645111,
#         2.82779205,  2.98929855,  3.38496448,  4.7467969 ,  5.73224398,
#         5.71490944,  6.13653905,  6.05161315,  5.98244028,  5.12555214,
#         5.70316883,  6.34174346,  6.01726555,  6.64280567,  6.69336328,
#         7.7473642 ,  7.16598421,  7.42277306,  7.02308503,  6.77901715,
#         8.57174802,  9.43521628, 10.7400805 , 10.40629714,  9.52343027])

# %%
plt.figure(figsize=(16, 8))
g = sns.lineplot(data=random_walk)
g.set_title('Random Walk')
g.set_xlabel('Time index')
plt.show()

# %% [markdown]
# # 시계열 데이터의 특성
# - 1) trend : 시간의 변화에 따라 평균의 증가/감소 등의 패턴
# - 2) outliers : 이상치가 포함될 수 있음
# - 3) seasonality: 특정 간격동안 반복되는 경향
# - 4) abrupt changes.: 불균등한 급격한 변화
# - 5) constant variance : 일정수준의  변동 또는 분산
